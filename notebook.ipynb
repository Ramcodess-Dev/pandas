# %%
import pandas as pd

df = pd.read_csv("orders.csv")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     str
#  2   Product       40 non-null     str
#  3   Category      40 non-null     str
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     str
#  7   Shipped       40 non-null     str
#  8   Country       40 non-null     str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 2.9 KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
len(df["Country"])
# Out:
# 40

# %%
set(df["Country"])
# Out:
# {'Argentina',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'Colombia',
#  'Egypt',
#  'France',
#  'Germany',
#  'India',
#  'Iran',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Pakistan',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Saudi Arabia',
#  'Singapore',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'UAE',
#  'UK',
#  'USA',
#  'Ukraine'}

# %%
df[["Country", "Product"]]
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
df.iloc[5]
# Out:
# OrderID                 1006
# CustomerName    Nora Ibrahim
# Product             Notebook
# Category          Stationery
# Quantity                   5
# Price                    5.0
# OrderDate         2024-06-07
# Shipped                  Yes
# Country                  UAE
# Name: 5, dtype: object

# %%
list(df.iloc[10])
# Out:
# [np.int64(1011),
#  'Sophie Martin',
#  'Webcam',
#  'Electronics',
#  np.int64(1),
#  np.float64(85.0),
#  '2024-06-12',
#  'Yes',
#  'France']

# %%
list(df.iloc[3])
# Out:
# [np.int64(1004),
#  'Alice Wong',
#  'Desk Lamp',
#  'Furniture',
#  np.int64(3),
#  np.float64(45.0),
#  '2024-06-05',
#  'Yes',
#  'Singapore']

# %%
df.iloc[10]["Country"]
# Out:
# 'France'
